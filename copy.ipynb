# %% [markdown]
# # PSO

# %% [markdown]
# Function:
# $
# f = x^2 + y^2 + 1
# $

# %%
from IPython.display import Image
from IPython.core.display import HTML 
Image(url= "https://www.researchgate.net/profile/Malek_Sarhani/post/What_is_Velocity_in_Particle_Swarm_Optimization/attachment/5abfe2ccb53d2f63c3c3245d/AS%3A610191980630016%401522492513881/image/PSOEquation.png")
# Out:
# <img src="https://www.researchgate.net/profile/Malek_Sarhani/post/What_is_Velocity_in_Particle_Swarm_Optimization/attachment/5abfe2ccb53d2f63c3c3245d/AS%3A610191980630016%401522492513881/image/PSOEquation.png"/>

# %% [markdown]
# # Implement

# %%
import random as rd
import numpy as np
import matplotlib.pyplot as plt
rd.seed(12)

# %%
W = 0.5
c1 = 0.8
c2 = 0.9

# %%
n_iterations = 50
n_particles = 30
target_error = 1e-6

# %%
class Particle():
    def __init__(self):
        x = (-1) ** bool(rd.getrandbits(1)) * rd.random() * 1000
        print("x looks like", x)
        y = (-1) ** bool(rd.getrandbits(1)) * rd.random() * 1000
        self.position = np.array([x, y])
        self.pBest_position = self.position
        self.pBest_value = float('inf') #this
        self.velocity = np.array([0,0])

    def update(self):
        self.position = self.position + self.velocity

# %%
class Space():
    def __init__(self, target, target_error, n_particles):
        #self.target = target
        #self.target_error = target_error
        self.n_particles = n_particles
        self.particles = []
        self.gBest_value = float('inf')
        self.gBest_position = np.array([rd.random() * 50, rd.random() * 50])
            
    def fitness(self, particle):
        x = particle.position[0]
        y = particle.position[1]
        f =  x**2 + y**2 + 1
        return f
    
    def set_pBest(self):
        for particle in self.particles:
            fitness_candidate = self.fitness(particle)
            if(particle.pBest_value > fitness_candidate):
                particle.pBest_value = fitness_candidate
                particle.pBest_position = particle.position
                
    def set_gBest(self):
        for particle in self.particles:
            best_fitness_candidate = self.fitness(particle)
            if(self.gBest_value > best_fitness_candidate):
                self.gBest_value = best_fitness_candidate
                self.gBest_position = particle.position
                
    def update_particles(self):
        for particle in self.particles:
            global W
            inertial = W * particle.velocity
            self_confidence = c1 * rd.random() * (particle.pBest_position - particle.position)
            swarm_confidence = c2 * rd.random() * (self.gBest_position - particle.position)
            new_velocity = inertial + self_confidence + swarm_confidence
            particle.velocity = new_velocity
            particle.update()
            
    def show_particles(self, iteration):        
        print(iteration, 'iterations')
        print('BestPosition in this time:', self.gBest_position)
        print('BestValue in this time:', self.gBest_value)
        
        for particle in self.particles:
            plt.plot(particle.position[0], particle.position[1], 'ro')
        plt.plot(self.gBest_position[0], self.gBest_position[1], 'bo')
        plt.show()

# %%
search_space = Space(1, target_error, n_particles)
particle_vector = [Particle() for _ in range(search_space.n_particles)]
search_space.particles = particle_vector

iteration = 0
while(iteration < n_iterations):
    # set particle best & global best
    search_space.set_pBest()
    search_space.set_gBest()

    # visualization
    search_space.show_particles(iteration)
    
    # check conditional
    #if(abs(search_space.gBest_value - search_space.target) <= search_space.target_error):
     #   break
        
    search_space.update_particles()
    iteration += 1
    
print("The best solution is: ", search_space.gBest_position, " in ", iteration, " iterations")
# Out:
# x looks like -349.7853736773159
# x looks like 482.5388139042864
# x looks like -864.3445417393523
# x looks like -624.2328818537502
# x looks like 339.68017925301916
# x looks like -199.63357653177994
# x looks like 681.4362362370958
# x looks like 918.9067114948085
# x looks like -223.24397482706593
# x looks like -443.7431999484273
# x looks like 539.4906499426118
# x looks like 976.1541463198846
# x looks like 507.2476701117876
# x looks like 668.1489318309052
# x looks like 541.1491619832394
# x looks like -191.86640513169584
# x looks like 941.0878223413865
# x looks like -309.90261669332085
# x looks like 371.26603358500074
# x looks like -179.4084685157482
# x looks like 32.714780561605814
# x looks like 43.48347625319748
# x looks like 753.2957088200104
# x looks like -273.78696975742344
# x looks like 602.0678105721595
# x looks like 368.3055580317485
# x looks like 696.9477680232234
# x looks like -988.5284242597445
# x looks like 181.90131477439607
# x looks like -606.9135070344377
# 0 iterations
# BestPosition in this time: [ 32.71478056 222.16795143]
# BestValue in this time: 50429.85551080791
# 1 iterations
# BestPosition in this time: [-34.9771432  -42.69141531]
# BestValue in this time: 3046.9574878629082
# 2 iterations
# BestPosition in this time: [-23.26476691   3.13580298]
# BestValue in this time: 552.0826398784026
# 3 iterations
# BestPosition in this time: [-23.26476691   3.13580298]
# BestValue in this time: 552.0826398784026
# 4 iterations
# BestPosition in this time: [-0.71964956  4.10260389]
# BestValue in this time: 18.349254165169626
# 5 iterations
# BestPosition in this time: [-0.71964956  4.10260389]
# BestValue in this time: 18.349254165169626
# 6 iterations
# BestPosition in this time: [ 3.0457236  -1.95943248]
# BestValue in this time: 14.115807909803223
# 7 iterations
# BestPosition in this time: [ 3.0457236  -1.95943248]
# BestValue in this time: 14.115807909803223
# 8 iterations
# BestPosition in this time: [ 3.0457236  -1.95943248]
# BestValue in this time: 14.115807909803223
# 9 iterations
# BestPosition in this time: [-1.2912905  -0.42166229]
# BestValue in this time: 2.845230247586313
# 10 iterations
# BestPosition in this time: [0.0357192  1.11538766]
# BestValue in this time: 2.245365497294103
# 11 iterations
# BestPosition in this time: [-0.42464535 -0.06942589]
# BestValue in this time: 1.185143629691053
# 12 iterations
# BestPosition in this time: [-0.03691606 -0.2705884 ]
# BestValue in this time: 1.0745808799683367
# 13 iterations
# BestPosition in this time: [-0.03691606 -0.2705884 ]
# BestValue in this time: 1.0745808799683367
# 14 iterations
# BestPosition in this time: [-0.03691606 -0.2705884 ]
# BestValue in this time: 1.0745808799683367
# 15 iterations
# BestPosition in this time: [ 0.00089899 -0.25767017]
# BestValue in this time: 1.066394724501171
# 16 iterations
# BestPosition in this time: [-0.10759353  0.02018987]
# BestValue in this time: 1.0119839977701812
# 17 iterations
# BestPosition in this time: [ 0.05074128 -0.06414674]
# BestValue in this time: 1.0066894818454541
# 18 iterations
# BestPosition in this time: [ 0.05074128 -0.06414674]
# BestValue in this time: 1.0066894818454541
# 19 iterations
# BestPosition in this time: [ 0.05074128 -0.06414674]
# BestValue in this time: 1.0066894818454541
# 20 iterations
# BestPosition in this time: [-0.05144004  0.02930073]
# BestValue in this time: 1.0035046106845755
# 21 iterations
# BestPosition in this time: [-0.01302367 -0.01578655]
# BestValue in this time: 1.0004188310303332
# 22 iterations
# BestPosition in this time: [-0.00167438 -0.00623659]
# BestValue in this time: 1.000041698545773
# 23 iterations
# BestPosition in this time: [-0.00167438 -0.00623659]
# BestValue in this time: 1.000041698545773
# 24 iterations
# BestPosition in this time: [-0.00167438 -0.00623659]
# BestValue in this time: 1.000041698545773
# 25 iterations
# BestPosition in this time: [-0.00167438 -0.00623659]
# BestValue in this time: 1.000041698545773
# 26 iterations
# BestPosition in this time: [-0.00062027 -0.00422878]
# BestValue in this time: 1.0000182673364693
# 27 iterations
# BestPosition in this time: [-0.00062027 -0.00422878]
# BestValue in this time: 1.0000182673364693
# 28 iterations
# BestPosition in this time: [0.00087494 0.00317596]
# BestValue in this time: 1.0000108522745867
# 29 iterations
# BestPosition in this time: [-0.002406   -0.00174076]
# BestValue in this time: 1.0000088190643965
# 30 iterations
# BestPosition in this time: [-0.002406   -0.00174076]
# BestValue in this time: 1.0000088190643965
# 31 iterations
# BestPosition in this time: [-0.00086006 -0.00127807]
# BestValue in this time: 1.0000023731497036
# 32 iterations
# BestPosition in this time: [-0.00096646  0.00043197]
# BestValue in this time: 1.0000011206416812
# 33 iterations
# BestPosition in this time: [-0.00096646  0.00043197]
# BestValue in this time: 1.0000011206416812
# 34 iterations
# BestPosition in this time: [-0.00043768  0.00018029]
# BestValue in this time: 1.0000002240717005
# 35 iterations
# BestPosition in this time: [-0.00019899  0.00025697]
# BestValue in this time: 1.000000105632248
# 36 iterations
# BestPosition in this time: [-2.82154867e-05  3.10253787e-04]
# BestValue in this time: 1.0000000970535257
# 37 iterations
# BestPosition in this time: [-2.82154867e-05  3.10253787e-04]
# BestValue in this time: 1.0000000970535257
# 38 iterations
# BestPosition in this time: [3.45984156e-05 2.12138273e-04]
# BestValue in this time: 1.0000000461996972
# 39 iterations
# BestPosition in this time: [1.17051928e-04 5.30516368e-05]
# BestValue in this time: 1.00000001651563
# 40 iterations
# BestPosition in this time: [5.79543630e-05 4.44051612e-06]
# BestValue in this time: 1.0000000033784264
# 41 iterations
# BestPosition in this time: [1.42289982e-05 5.56722929e-05]
# BestValue in this time: 1.0000000033018686
# 42 iterations
# BestPosition in this time: [ 5.18802966e-05 -1.05643755e-05]
# BestValue in this time: 1.0000000028031713
# 43 iterations
# BestPosition in this time: [-2.46171862e-05  2.41047827e-05]
# BestValue in this time: 1.0000000011870465
# 44 iterations
# BestPosition in this time: [2.47180312e-06 2.07494528e-06]
# BestValue in this time: 1.0000000000104152
# 45 iterations
# BestPosition in this time: [2.47180312e-06 2.07494528e-06]
# BestValue in this time: 1.0000000000104152
# 46 iterations
# BestPosition in this time: [2.47180312e-06 2.07494528e-06]
# BestValue in this time: 1.0000000000104152
# 47 iterations
# BestPosition in this time: [2.47180312e-06 2.07494528e-06]
# BestValue in this time: 1.0000000000104152
# 48 iterations
# BestPosition in this time: [2.47180312e-06 2.07494528e-06]
# BestValue in this time: 1.0000000000104152
# 49 iterations
# BestPosition in this time: [ 5.76625284e-07 -1.21158865e-06]
# BestValue in this time: 1.0000000000018003
# The best solution is:  [ 5.76625284e-07 -1.21158865e-06]  in  50  iterations
