# %% [markdown]
# ## Comparison of PSO and GA

# %%
from optproblems import cec2005
import ga.ga_functions as ga
import numpy as np

# %% [markdown]
# ### Comparing Different Benchmark Functions for PSO and GA

# %%
function0 = cec2005.F1
function1 = cec2005.F2
function2 = cec2005.F9
function3 = cec2005.F11

test_f0 = ga.GA(function0(10), -100, 100, 10, 100, 100) # -450 minima
test_f1 = ga.GA(function1(10), -100, 100, 10, 100, 400) # -450 minima
test_f2 = ga.GA(function2(10), -5, 5, 10, 100, 100) # -330 minima
test_f3 = ga.GA(function3(10), -0.5, 0.5, 10, 100, 1100) # 90 minima

variablef0, minimaf0, genf0 = test_f0.run_ga()
variablef1, minimaf1, genf1 = test_f1.run_ga()
variablef2, minimaf2, genf2 = test_f2.run_ga()
variablef3, minimaf3, genf3 = test_f3.run_ga()

print(f"\nThe minima reached for function cec2005.F1() is {minimaf0} at Generation {genf0}.\nBest population is {variablef0}")
print(f"\nThe minima reached for function cec2005.F2() is {minimaf1} at Generation {genf1}.\nBest population is {variablef1}")
print(f"\nThe minima reached for function cec2005.F9() is {minimaf2} at Generation {genf2}.\nBest population is {variablef2}")
print(f"\nThe minima reached for function cec2005.F11() is {minimaf3} at Generation {genf3}.\nBest population is {variablef3}")
# Out:
# The minima reached for function cec2005.F1() is -449.746924655062 at Generation 90.
# Best population is [-39.04407496581475, 59.912185805903746, -45.56831303134008, -72.83859306000431, -15.96478878939452, -80.24329984558882, -8.99515464553119, 23.72968620086944, 91.10818553690014, 9.248378746084057]
#
# The minima reached for function cec2005.F2() is -449.4722661381815 at Generation 379.
# Best population is [37.5534162532633, -82.58010256992478, -9.84467236599688, -82.5194967497781, 81.95604384670445, 45.53532805388598, -88.76872644184753, -27.454259181864686, 74.47613757127274, -37.802697132041125]
#
# The minima reached for function cec2005.F9() is -322.97765628099825 at Generation 94.
# Best population is [1.8515335097452228, -0.5456827971829044, -0.9568578988554236, -1.2163497873902784, 3.4873631942729872, -4.323696068464963, 1.9991331811300088, -3.6239779787106117, 0.12093513661731511, -3.257761913365958]
#
# The minima reached for function cec2005.F11() is 97.29751609002308 at Generation 477.
# Best population is [0.47955016071383494, 0.1707079999617836, 0.24891703556012057, -0.3407243012067904, 0.28146884675924244, 0.35568569761443647, -0.4419678982911563, 0.47329658177492323, -0.17334025062765293, 0.07534704517603874]

# %%
import PSO

test_f0 = PSO.PSO(lbound = -100, ubound = 100, size = 100, iters =300, obj=function0) # -450 minima
test_f1 = PSO.PSO(lbound = -100, ubound = 100, size = 100, iters = 300, obj=function1) # -450 minima
test_f2 = PSO.PSO(lbound = -5, ubound = 5, size =100, iters = 300, obj=function2) # -330 minima
test_f3 = PSO.PSO(lbound = -0.5, ubound = 0.5, size = 100, iters = 300, obj=function3) # 90 minima

test_f0.optimize()
test_f1.optimize()
test_f2.optimize() 
test_f3.optimize()

print(f"\nThe minima reached for function cec2005.F1() is {test_f0.gBest} at Iteration {test_f0.bestiter}.\nThe best position is {test_f0.gBestPos}")
print(f"\nThe minima reached for function cec2005.F2() is {test_f1.gBest} at Iteration {test_f1.bestiter}.\nThe best position is {test_f1.gBestPos}")
print(f"\nThe minima reached for function cec2005.F9() is {test_f2.gBest} at Iteration {test_f2.bestiter}.\nThe best position is {test_f2.gBestPos}")
print(f"\nThe minima reached for function cec2005.F11() is {test_f3.gBest} at Iteration {test_f2.bestiter}.\nThe best position is {test_f3.gBestPos}")
# Out:
# The minima reached for function cec2005.F1() is -449.86401071593497 at Iteration 299.
# The best position is [-39.15754414  58.78865846 -46.30110937 -74.77953479 -16.90036732
#  -80.44037526 -10.46686852  25.08716816  89.83792141   8.93261016]
#
# The minima reached for function cec2005.F2() is -449.58923730253406 at Iteration 299.
# The best position is [ 35.3622541  -82.25011786 -11.33176383 -83.24684409  83.20414003
#   46.87062328 -89.20086653 -27.79659077  76.44495778 -39.16993917]
#
# The minima reached for function cec2005.F9() is -321.04537352397944 at Iteration 140.
# The best position is [ 2.89545864 -1.56440001 -1.97375863 -0.26368777  1.50404137 -3.28530001
#   0.9759     -2.67114137  1.09345864 -3.24649999]
#
# The minima reached for function cec2005.F11() is 94.14214331388662 at Iteration 140.
# The best position is [ 0.30625712 -0.19790007 -0.07469749 -0.41935504  0.37503596 -0.01106786
#  -0.16880264 -0.23889636 -0.32708081  0.1136687 ]
