# %% [markdown]
# ## Comparison of PSO and GA

# %%
from optproblems import cec2005
import ga.ga_functions as ga
import numpy as np

# %% [markdown]
# ### Comparing Different Benchmark Functions for PSO and GA

# %%
function0 = cec2005.F1(10)
function1 = cec2005.F3(10)
function2 = cec2005.F9(10)
function3 = cec2005.F11(10)

test_f0 = ga.GA(function0, -100, 100, 10, 100, 100)
test_f1 = ga.GA(function1, -100, 100, 10, 100, 100)
test_f2 = ga.GA(function2, -5, 5, 10, 100, 100)
test_f3 = ga.GA(function3, -0.5, 0.5, 10, 100, 1000)

variablef0, minimaf0, genf0 = test_f0.run_ga()
variablef1, minimaf1, genf1 = test_f1.run_ga()
variablef2, minimaf2, genf2 = test_f2.run_ga()
variablef3, minimaf3, genf3 = test_f3.run_ga()

print(f"The minima reached for function cec2005.F1() is {minimaf0} at Generation {genf0}.")
print(f"The minima reached for function cec2005.F4() is {minimaf1} at Generation {genf1}.")
print(f"The minima reached for function cec2005.F8() is {minimaf2} at Generation {genf2}.")
print(f"The minima reached for function cec2005.F20() is {minimaf3} at Generation {genf3}.")
# Out:
# The minima reached for function cec2005.F1() is -449.35487246426305 at Generation 67.
# The minima reached for function cec2005.F4() is -443.8503281297657 at Generation 98.
# The minima reached for function cec2005.F8() is -119.27968027123904 at Generation 8.
# The minima reached for function cec2005.F20() is 728.8544485020253 at Generation 80.
